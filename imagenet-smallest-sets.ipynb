# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aangelopoulos/conformal-prediction/blob/main/notebooks/imagenet-smallest-sets.ipynb)

# %% [markdown]
# ### Illustration of Conformal Prediction

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Requirement already satisfied: gdown in /home/adithyakanil/myenv/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Load cached data
if not os.path.exists('../data'):
    os.system('gdown 1h7S6N_Rx7gdfO3ZunzErZy6H7620EbZK -O ../data.tar.gz')
    os.system('tar -xf ../data.tar.gz -C ../')
    os.system('rm ../data.tar.gz')
if not os.path.exists('../data/imagenet/human_readable_labels.json'):
    # !wget -nv -O ../data/imagenet/human_readable_labels.json -L https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json

data = np.load('../data/imagenet/imagenet-resnet152.npz')
example_paths = os.listdir('../data/imagenet/examples')
smx = data['smx']
labels = data['labels'].astype(int)

# %%
# Problem setup
n=1000 # number of calibration points
alpha = 0.1 # 1-alpha is the desired coverage

# %%
# Split the softmax scores into calibration and validation sets (save the shuffling)
idx = np.array([1] * n + [0] * (smx.shape[0]-n)) > 0
np.random.shuffle(idx)
cal_smx, val_smx = smx[idx,:], smx[~idx,:]
cal_labels, val_labels = labels[idx], labels[~idx]

# %% [markdown]
# ### Conformal prediction happens here

# %%
# 1: get conformal scores. n = calib_Y.shape[0]
cal_scores = 1-cal_smx[np.arange(n),cal_labels]
# 2: get adjusted quantile
q_level = np.ceil((n+1)*(1-alpha))/n
qhat = np.quantile(cal_scores, q_level, interpolation='higher')
prediction_sets = val_smx >= (1-qhat) # 3: form prediction sets

# %%
# Calculate empirical coverage
empirical_coverage = prediction_sets[np.arange(prediction_sets.shape[0]),val_labels].mean()
print(f"The empirical coverage is: {empirical_coverage}")
# Out:
# The empirical coverage is: 0.8856938775510204

# %%
# Show some examples
with open('../data/imagenet/human_readable_labels.json') as f:
    label_strings = np.array(json.load(f))

example_paths =os.listdir('../data/imagenet/examples')
for i in range(10):
    rand_path = np.random.choice(example_paths)
    img = imread('../data/imagenet/examples/' + rand_path )
    img_index = int(rand_path.split('.')[0])
    prediction_set = smx[img_index] > 1-qhat
    plt.figure()
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    print(f"The prediction set is: {list(label_strings[prediction_set])}")
# Out:
# The prediction set is: [np.str_('chainsaw')]
# The prediction set is: [np.str_('Irish Setter'), np.str_('Cocker Spaniels')]
# The prediction set is: [np.str_('medicine chest')]
# The prediction set is: [np.str_('moped'), np.str_('scooter')]
# The prediction set is: [np.str_('confectionery store'), np.str_('grocery store'), np.str_('toy store')]
# The prediction set is: [np.str_('red fox'), np.str_('kit fox'), np.str_('grey fox')]
# The prediction set is: [np.str_('cheetah')]
# The prediction set is: [np.str_('Maltese'), np.str_('Norfolk Terrier'), np.str_('Yorkshire Terrier')]
# The prediction set is: [np.str_('Ibizan Hound')]
# The prediction set is: [np.str_('horizontal bar')]

# %% [markdown]
# ### This method leads to small sets, but sacrifices adaptivity. [Click this link](https://github.com/aangelopoulos/conformal-prediction/blob/main/notebooks/imagenet-raps.ipynb) for an improvement.

# %% [markdown]
# This method was studied in https://arxiv.org/abs/1609.00451.
