# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aangelopoulos/conformal-prediction/blob/main/notebooks/imagenet-raps.ipynb)

# %% [markdown]
# ### Improvised Adaptive Prediction Sets

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Requirement already satisfied: gdown in /home/adithyakanil/myenv/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /home/adithyakanil/myenv/lib/python3.12/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/adithyakanil/myenv/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Load cached data
if not os.path.exists('../data'):
    os.system('gdown 1h7S6N_Rx7gdfO3ZunzErZy6H7620EbZK -O ../data.tar.gz')
    os.system('tar -xf ../data.tar.gz -C ../')
    os.system('rm ../data.tar.gz')
if not os.path.exists('../data/imagenet/human_readable_labels.json'):
    # !wget -nv -O ../data/imagenet/human_readable_labels.json -L https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json

data = np.load('../data/imagenet/imagenet-resnet152.npz')
example_paths = os.listdir('../data/imagenet/examples')
smx = data['smx']
labels = data['labels'].astype(int)

# %%
# Problem setup
n=1000 # number of calibration points
alpha = 0.1 # 1-alpha is the desired coverage
# Set RAPS regularization parameters (larger lam_reg and smaller k_reg leads to smaller sets)
lam_reg = 0.01
k_reg = 5
disallow_zero_sets = False # Set this to False in order to see the coverage upper bound hold
rand = True # Set this to True in order to see the coverage upper bound hold
reg_vec = np.array(k_reg*[0,] + (smx.shape[1]-k_reg)*[lam_reg,])[None,:]

# %%
# Split the softmax scores into calibration and validation sets (save the shuffling)
idx = np.array([1] * n + [0] * (smx.shape[0]-n)) > 0
np.random.shuffle(idx)
cal_smx, val_smx = smx[idx,:], smx[~idx,:]
cal_labels, val_labels = labels[idx], labels[~idx]

# %% [markdown]
# ### Conformal prediction happens here

# %%
# Get scores. calib_X.shape[0] == calib_Y.shape[0] == n
cal_pi = cal_smx.argsort(1)[:,::-1]; 
cal_srt = np.take_along_axis(cal_smx,cal_pi,axis=1)
cal_srt_reg = cal_srt + reg_vec
cal_L = np.where(cal_pi == cal_labels[:,None])[1]
cal_scores = cal_srt_reg.cumsum(axis=1)[np.arange(n),cal_L] - np.random.rand(n)*cal_srt_reg[np.arange(n),cal_L]
# Get the score quantile
qhat = np.quantile(cal_scores, np.ceil((n+1)*(1-alpha))/n, interpolation='higher')
# Deploy
n_val = val_smx.shape[0]
val_pi = val_smx.argsort(1)[:,::-1]
val_srt = np.take_along_axis(val_smx,val_pi,axis=1)
val_srt_reg = val_srt + reg_vec
val_srt_reg_cumsum = val_srt_reg.cumsum(axis=1)
indicators = (val_srt_reg.cumsum(axis=1) - np.random.rand(n_val,1)*val_srt_reg) <= qhat if rand else val_srt_reg.cumsum(axis=1) - val_srt_reg <= qhat
if disallow_zero_sets: indicators[:,0] = True
prediction_sets = np.take_along_axis(indicators,val_pi.argsort(axis=1),axis=1)

# %%
# Calculate empirical coverage
empirical_coverage = prediction_sets[np.arange(n_val),val_labels].mean()
print(f"The empirical coverage is: {empirical_coverage}")
print(f"The quantile is: {qhat}")
# Out:
# The empirical coverage is: 0.906530612244898
# The quantile is: 0.955764360244019

# %%
# Show some examples
with open('../data/imagenet/human_readable_labels.json') as f:
    label_strings = np.array(json.load(f))

example_paths =os.listdir('../data/imagenet/examples')
for i in range(10):
    rand_path = np.random.choice(example_paths)
    img = imread('../data/imagenet/examples/' + rand_path )
    img_index = int(rand_path.split('.')[0])
    # Form the prediction set
    _smx = smx[img_index]
    _pi = np.argsort(_smx)[::-1]
    _srt = np.take_along_axis(_smx,_pi,axis=0)
    _srt_reg = _srt + reg_vec.squeeze()
    _srt_reg_cumsum = _srt_reg.cumsum()
    _ind = (_srt_reg_cumsum - np.random.rand()*_srt_reg) <= qhat if rand else _srt_reg_cumsum - _srt_reg <= qhat
    if disallow_zero_sets: _ind[0] = True
    prediction_set = np.take_along_axis(_ind,_pi.argsort(),axis=0)
    plt.figure()
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    print(f"The prediction set is: {list(label_strings[prediction_set])}")
# Out:
# The prediction set is: [np.str_('great grey owl')]
# The prediction set is: [np.str_('Norwich Terrier'), np.str_('Yorkshire Terrier'), np.str_('Australian Terrier'), np.str_('Australian Silky Terrier')]
# The prediction set is: [np.str_('Japanese Chin'), np.str_('Pekingese')]
# The prediction set is: [np.str_('sleeping bag'), np.str_('stretcher')]
# The prediction set is: [np.str_('bassinet'), np.str_('cradle')]
# The prediction set is: [np.str_('coral fungus')]
# The prediction set is: [np.str_('binoculars')]
# The prediction set is: [np.str_('barn spider'), np.str_('wolf spider')]
# The prediction set is: [np.str_('pencil sharpener')]
# The prediction set is: [np.str_('bow tie'), np.str_('mobile phone'), np.str_('computer keyboard'), np.str_('cowboy hat'), np.str_('desktop computer'), np.str_('football helmet'), np.str_('hand-held computer'), np.str_('home theater'), np.str_('laptop computer'), np.str_('slip-on shoe'), np.str_('speaker'), np.str_('monitor'), np.str_('notebook computer'), np.str_('CRT screen'), np.str_('stage'), np.str_('suit'), np.str_('sunglass'), np.str_('sunglasses'), np.str_('television'), np.str_('website')]

# %% [markdown]
# This method was first introduced in https://arxiv.org/abs/2009.14193.
